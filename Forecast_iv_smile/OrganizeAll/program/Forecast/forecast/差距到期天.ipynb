# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
def Slope(X, Y, axis=1):
    sorted_idx = np.argsort(X, axis=axis)
    X = np.take_along_axis(X, sorted_idx, axis=axis)
    Y = np.take_along_axis(Y, sorted_idx, axis=axis)
    if axis==1:
        delta_X = X[:,1:] - X[:,:-1]
        delta_Y = Y[:,1:] - Y[:,:-1]
    if axis==0:
        delta_X = X[1:] - X[:-1]
        delta_Y = Y[1:] - Y[:-1]
    return delta_Y / delta_X

def recovery_curve(x, slope, y0=0.5):
    delta_x = x[1:] - x[:-1]
    delta_y = delta_x*slope
    y = np.array([delta_y[:i].sum() for i in range(1, len(x), 1)]) + y0
    y = np.hstack((np.array([y0]), y))
    return y
IVdir = 'callIV'
OCRange = 1
lower_range = 0
upper_range = 800

top_path = './../../../'

ForecastPath = top_path + 'Data/Forecast/'

file = top_path + 'Data/Interpolate/{}/{}/{}_{}.csv'.format(IVdir, OCRange, lower_range, upper_range)
if IVdir not in os.listdir(ForecastPath):
    os.mkdir(ForecastPath + '{}'.format(IVdir))

if str(OCRange) not in os.listdir(ForecastPath + '{}'.format(IVdir)):
    os.mkdir(ForecastPath + '{}/{}'.format(IVdir, OCRange))

if '{}_{}'.format(lower_range, upper_range) not in \
os.listdir(ForecastPath + '{}/{}'.format(IVdir, OCRange)):
    os.mkdir(ForecastPath + '{}/{}/{}_{}'.format(IVdir, OCRange, lower_range, upper_range))
output_dir_path = ForecastPath + '{}/{}/{}_{}/'.format(IVdir, OCRange, lower_range, upper_range)

IV_data = pd.read_csv(file, encoding='Big5', index_col=False)

#IV_data = IV_data[IV_data['到期天數'] > 2]
#IV_data = IV_data[IV_data['到期天數'] < 30]


OC = abs(np.array(IV_data['期貨開盤價'] - IV_data['期貨收盤價']))
HL = np.array(IV_data['期貨最高價'] - IV_data['期貨最低價'])
expirty_days = np.array(IV_data['到期天數'])
OCHLE = np.vstack((OC, HL, expirty_days)).T





IV_matrix = np.array(IV_data)
K_num = len(np.where(IV_matrix[0,0] == IV_matrix)[0])
K_closing = np.array(IV_data['履約價(收盤價)'])
K_closing = np.reshape(K_closing, (-1, K_num))
IV_closing = np.array(IV_data['隱含波動率(收盤價)'])
IV_closing = np.reshape(IV_closing, (-1, K_num))
K_IVslope_closing = Slope(X=K_closing, Y=IV_closing, axis=1)

K_settlement = np.array(IV_data['履約價(結算價)'])
K_settlement = np.reshape(K_settlement, (-1, K_num))
IV_settlement = np.array(IV_data['隱含波動率(結算價)'])
IV_settlement = np.reshape(IV_settlement, (-1, K_num))
K_IVslope_settlement = Slope(X=K_settlement, Y=IV_settlement, axis=1)


k = 20
plt.style.use('seaborn-darkgrid')
plt.plot(K_settlement[k], IV_settlement[k], lw=1, ls='-', marker='o', c=[0.5, 0.5, 0.8], label='volatility smiles')
#plt.plot([Udata[k,4]]*2, [Kmin, Kmax], lw=1, ls='--', c=[0.8, 0.5, 0.5], label='futures price')
plt.xlabel('K')
plt.ylabel('Implied Volatility')
plt.legend()
plt.show()

#x = np.arange(1, K_num+1, 1)
#y_right = 0.2
#y = np.array([K_IVslope[k,:i].sum() for i in range(1, K_num, 1)]) + y_right
#y = np.hstack((np.array([y_right]), y))
y = recovery_curve(K_settlement[k], K_IVslope_settlement[k])
plt.style.use('seaborn-darkgrid')
plt.plot(K_settlement[k], y, lw=1, ls='-', marker='o', c=[0.5, 0.5, 0.8], label='volatility smiles')
#plt.plot([Udata[k,4]]*2, [Kmin, Kmax], lw=1, ls='--', c=[0.8, 0.5, 0.5], label='futures price')
plt.xlabel('K')
plt.ylabel('Implied Volatility')
plt.legend()
plt.show()
# Out:
# C:\Users\bgpa4\AppData\Local\Temp\ipykernel_25348\4031659670.py:75: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')
# C:\Users\bgpa4\AppData\Local\Temp\ipykernel_25348\4031659670.py:88: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %% [markdown]
# 若$X=[x_1, x_2,\dots x_n     ]$
# 則 $TimeSeriesData(X, 30)= [[x_1, x_2,\dots x_{30}],\quad [x_2, x_3,\dots x_{31}]\dots [x_{n-30}, x_{n-29},\dots x_{n-1}]],\quad [x_{31}, x_{32},\dots x_n     ]$

# %%
def TimeSeriesData(X, seq_length):
    X_train = np.zeros((len(X)-seq_length, seq_length, len(X[0])))
    y_train = np.zeros((len(X)-seq_length, len(X[0])))
    for i in range(len(X) - seq_length):
        X_train[i] = X[i:i+seq_length]
        y_train[i] = (X[i+seq_length])
    return np.array(X_train), np.array(y_train)
seq_length = 7
magnification_slope = 10000
IV_matrix_forecast = IV_matrix[seq_length*K_num:]
#收盤價
Inputs_closing_slope, Ouputs_closing = TimeSeriesData(K_IVslope_closing*magnification_slope, seq_length=seq_length)

Inputs_OHLCE = OCHLE[range(0, len(IV_matrix), K_num)]
Inputs_OHLCE = np.array([Inputs_OHLCE[i:i+seq_length+1] for i in range(len(Inputs_OHLCE)-seq_length)])
Inputs_OHLCE = Inputs_OHLCE.astype(float)

train_size = int(len(Inputs_closing_slope)*0.8)
X_train_closing = Inputs_closing_slope[:train_size]
OHLCE_train = Inputs_OHLCE[:train_size]
y_train_closing = Ouputs_closing[:train_size]
X_test_closing = Inputs_closing_slope[train_size:]
y_test_closing = Ouputs_closing[train_size:]
IV_matrix_test = IV_matrix_forecast[K_num*train_size:]
OHLCE_test = Inputs_OHLCE[train_size:]


#結算價
Inputs_settlement, Ouputs_settlement = TimeSeriesData(K_IVslope_settlement*magnification_slope, seq_length=seq_length)
train_size = int(len(Inputs_settlement)*0.8)
X_train_settlement = Inputs_settlement[:train_size]
y_train_settlement = Ouputs_settlement[:train_size]
X_test_settlement = Inputs_settlement[train_size:]
y_test_settlement = Ouputs_settlement[train_size:]

# %%
from keras.models import Model
from keras.layers import Input, Dense, LSTM, concatenate
from keras.optimizers import Adam

# 定義第一個ANN模型
input_lstm_OHLC = Input(shape=OHLCE_train.shape[1:])
hidden1_OHLC = LSTM(500, return_sequences=True, activation='relu')(input_lstm_OHLC)
hidden2_OHLC = LSTM(200, activation='relu')(hidden1_OHLC)
output_OHLC = Dense(100)(hidden2_OHLC)

# 定義第二個LSTM模型
input_lstm_slope = Input(shape=X_train_settlement.shape[1:])
#lstm1 = LSTM(200, return_sequences=True, activation='relu')(input_slope)
hidden1_slope = LSTM(128, activation='relu')(input_lstm_slope)
output_slope = Dense(100)(hidden1_slope)

# 合併兩個模型的輸出
#merged = concatenate([output_ann, dense_lstm], axis=-1)
merged = concatenate([output_OHLC, output_slope], axis=-1)

# 加入一個Dense層
dense1 = Dense(300, activation='relu')(merged)
dense2 = Dense(200, activation='relu')(dense1)
# 最終輸出層
output = Dense(y_train_closing.shape[1])(dense2)

# 定義模型
model = Model(inputs=[input_lstm_OHLC, input_lstm_slope], outputs=output)

# 編譯模型
#adam = Adam(learning_rate=0.1)
adam = Adam()
model.compile(loss='mse', optimizer = 'adam', metrics=['mse'])

# 顯示模型結構
#model.summary()



# 訓練模型
model.fit([OHLCE_train, X_train_settlement], y_train_settlement, epochs=50, \
          batch_size=3000, validation_split=0.2)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 4s 4s/step - loss: 18.6960 - mse: 18.6960 - val_loss: 29.3797 - val_mse: 29.3797
# Epoch 2/50
# 1/1 [==============================] - 1s 689ms/step - loss: 5.6099 - mse: 5.6099 - val_loss: 15.4797 - val_mse: 15.4797
# Epoch 3/50
# 1/1 [==============================] - 1s 689ms/step - loss: 3.8511 - mse: 3.8511 - val_loss: 8.5067 - val_mse: 8.5067
# Epoch 4/50
# 1/1 [==============================] - 1s 695ms/step - loss: 2.6879 - mse: 2.6879 - val_loss: 6.7172 - val_mse: 6.7172
# Epoch 5/50
# 1/1 [==============================] - 1s 679ms/step - loss: 2.1903 - mse: 2.1903 - val_loss: 6.9142 - val_mse: 6.9142
# Epoch 6/50
# 1/1 [==============================] - 1s 679ms/step - loss: 2.0732 - mse: 2.0732 - val_loss: 4.0523 - val_mse: 4.0523
# Epoch 7/50
# 1/1 [==============================] - 1s 685ms/step - loss: 1.9148 - mse: 1.9148 - val_loss: 5.2801 - val_mse: 5.2801
# Epoch 8/50
# 1/1 [==============================] - 1s 680ms/step - loss: 1.7686 - mse: 1.7686 - val_loss: 3.1117 - val_mse: 3.1117
# Epoch 9/50
# 1/1 [==============================] - 1s 672ms/step - loss: 1.6882 - mse: 1.6882 - val_loss: 4.4862 - val_mse: 4.4862
# Epoch 10/50
# 1/1 [==============================] - 1s 708ms/step - loss: 1.6100 - mse: 1.6100 - val_loss: 3.7851 - val_mse: 3.7851
# Epoch 11/50
# 1/1 [==============================] - 1s 678ms/step - loss: 1.5016 - mse: 1.5016 - val_loss: 2.0168 - val_mse: 2.0168
# Epoch 12/50
# 1/1 [==============================] - 1s 675ms/step - loss: 1.4262 - mse: 1.4262 - val_loss: 12.9215 - val_mse: 12.9215
# Epoch 13/50
# 1/1 [==============================] - 1s 672ms/step - loss: 1.9266 - mse: 1.9266 - val_loss: 1.5836 - val_mse: 1.5836
# Epoch 14/50
# 1/1 [==============================] - 1s 681ms/step - loss: 1.9620 - mse: 1.9620 - val_loss: 1.6234 - val_mse: 1.6234
# Epoch 15/50
# 1/1 [==============================] - 1s 704ms/step - loss: 2.1057 - mse: 2.1057 - val_loss: 1.7519 - val_mse: 1.7519
# Epoch 16/50
# 1/1 [==============================] - 1s 694ms/step - loss: 1.9813 - mse: 1.9813 - val_loss: 2.4404 - val_mse: 2.4404
# Epoch 17/50
# 1/1 [==============================] - 1s 691ms/step - loss: 1.8188 - mse: 1.8188 - val_loss: 2.9437 - val_mse: 2.9437
# Epoch 18/50
# 1/1 [==============================] - 1s 680ms/step - loss: 1.6839 - mse: 1.6839 - val_loss: 3.2222 - val_mse: 3.2222
# Epoch 19/50
# 1/1 [==============================] - 1s 677ms/step - loss: 1.5905 - mse: 1.5905 - val_loss: 3.8157 - val_mse: 3.8157
# Epoch 20/50
# 1/1 [==============================] - 1s 692ms/step - loss: 1.5347 - mse: 1.5347 - val_loss: 3.7751 - val_mse: 3.7751
# Epoch 21/50
# 1/1 [==============================] - 1s 695ms/step - loss: 1.4697 - mse: 1.4697 - val_loss: 2.9096 - val_mse: 2.9096
# Epoch 22/50
# 1/1 [==============================] - 1s 689ms/step - loss: 1.4012 - mse: 1.4012 - val_loss: 2.4208 - val_mse: 2.4208
# Epoch 23/50
# 1/1 [==============================] - 1s 726ms/step - loss: 1.3434 - mse: 1.3434 - val_loss: 2.7333 - val_mse: 2.7333
# Epoch 24/50
# 1/1 [==============================] - 1s 690ms/step - loss: 1.2623 - mse: 1.2623 - val_loss: 3.3025 - val_mse: 3.3025
# Epoch 25/50
# 1/1 [==============================] - 1s 681ms/step - loss: 1.2250 - mse: 1.2250 - val_loss: 1.5964 - val_mse: 1.5964
# Epoch 26/50
# 1/1 [==============================] - 1s 681ms/step - loss: 1.2314 - mse: 1.2314 - val_loss: 1.7007 - val_mse: 1.7007
# Epoch 27/50
# 1/1 [==============================] - 1s 687ms/step - loss: 1.1242 - mse: 1.1242 - val_loss: 6.8242 - val_mse: 6.8242
# Epoch 28/50
# 1/1 [==============================] - 1s 679ms/step - loss: 1.3080 - mse: 1.3080 - val_loss: 1.2513 - val_mse: 1.2513
# Epoch 29/50
# 1/1 [==============================] - 1s 711ms/step - loss: 1.1700 - mse: 1.1700 - val_loss: 1.0941 - val_mse: 1.0941
# Epoch 30/50
# 1/1 [==============================] - 1s 669ms/step - loss: 1.3067 - mse: 1.3067 - val_loss: 1.2409 - val_mse: 1.2409
# Epoch 31/50
# 1/1 [==============================] - 1s 661ms/step - loss: 1.1409 - mse: 1.1409 - val_loss: 2.5335 - val_mse: 2.5335
# Epoch 32/50
# 1/1 [==============================] - 1s 659ms/step - loss: 1.0243 - mse: 1.0243 - val_loss: 4.1254 - val_mse: 4.1254
# Epoch 33/50
# 1/1 [==============================] - 1s 664ms/step - loss: 1.1479 - mse: 1.1479 - val_loss: 2.4853 - val_mse: 2.4853
# Epoch 34/50
# 1/1 [==============================] - 1s 698ms/step - loss: 0.9340 - mse: 0.9340 - val_loss: 1.2749 - val_mse: 1.2749
# Epoch 35/50
# 1/1 [==============================] - 1s 675ms/step - loss: 0.8711 - mse: 0.8711 - val_loss: 1.2515 - val_mse: 1.2515
# Epoch 36/50
# 1/1 [==============================] - 1s 659ms/step - loss: 0.8577 - mse: 0.8577 - val_loss: 3.0960 - val_mse: 3.0960
# Epoch 37/50
# 1/1 [==============================] - 1s 700ms/step - loss: 0.8616 - mse: 0.8616 - val_loss: 1.7257 - val_mse: 1.7257
# Epoch 38/50
# 1/1 [==============================] - 1s 766ms/step - loss: 0.8076 - mse: 0.8076 - val_loss: 1.4948 - val_mse: 1.4948
# Epoch 39/50
# 1/1 [==============================] - 1s 721ms/step - loss: 0.7998 - mse: 0.7998 - val_loss: 2.5586 - val_mse: 2.5586
# Epoch 40/50
# 1/1 [==============================] - 1s 715ms/step - loss: 0.7628 - mse: 0.7628 - val_loss: 1.8113 - val_mse: 1.8113
# Epoch 41/50
# 1/1 [==============================] - 1s 717ms/step - loss: 0.7020 - mse: 0.7020 - val_loss: 1.9710 - val_mse: 1.9710
# Epoch 42/50
# 1/1 [==============================] - 1s 666ms/step - loss: 0.6696 - mse: 0.6696 - val_loss: 3.7470 - val_mse: 3.7470
# Epoch 43/50
# 1/1 [==============================] - 1s 655ms/step - loss: 0.6649 - mse: 0.6649 - val_loss: 1.7254 - val_mse: 1.7254
# Epoch 44/50
# 1/1 [==============================] - 1s 642ms/step - loss: 0.7061 - mse: 0.7061 - val_loss: 3.4102 - val_mse: 3.4102
# Epoch 45/50
# 1/1 [==============================] - 1s 662ms/step - loss: 0.5985 - mse: 0.5985 - val_loss: 4.0604 - val_mse: 4.0604
# Epoch 46/50
# 1/1 [==============================] - 1s 720ms/step - loss: 0.6168 - mse: 0.6168 - val_loss: 1.0803 - val_mse: 1.0803
# Epoch 47/50
# 1/1 [==============================] - 1s 707ms/step - loss: 0.6983 - mse: 0.6983 - val_loss: 1.8467 - val_mse: 1.8467
# Epoch 48/50
# 1/1 [==============================] - 1s 735ms/step - loss: 0.5701 - mse: 0.5701 - val_loss: 7.3415 - val_mse: 7.3415
# Epoch 49/50
# 1/1 [==============================] - 1s 773ms/step - loss: 0.7906 - mse: 0.7906 - val_loss: 0.9699 - val_mse: 0.9699
# Epoch 50/50
# 1/1 [==============================] - 1s 644ms/step - loss: 0.7566 - mse: 0.7566 - val_loss: 0.8539 - val_mse: 0.8539

# %%
model.fit([OHLCE_train, X_train_settlement], y_train_settlement, epochs=20, batch_size=3000, validation_split=0.2)
# Out:
# Epoch 1/20
# 1/1 [==============================] - 1s 805ms/step - loss: 0.3739 - mse: 0.3739 - val_loss: 1.2565 - val_mse: 1.2565
# Epoch 2/20
# 1/1 [==============================] - 1s 716ms/step - loss: 0.3713 - mse: 0.3713 - val_loss: 1.4259 - val_mse: 1.4259
# Epoch 3/20
# 1/1 [==============================] - 1s 736ms/step - loss: 0.3702 - mse: 0.3702 - val_loss: 1.3518 - val_mse: 1.3518
# Epoch 4/20
# 1/1 [==============================] - 1s 733ms/step - loss: 0.3670 - mse: 0.3670 - val_loss: 1.2057 - val_mse: 1.2057
# Epoch 5/20
# 1/1 [==============================] - 1s 759ms/step - loss: 0.3663 - mse: 0.3663 - val_loss: 1.3446 - val_mse: 1.3446
# Epoch 6/20
# 1/1 [==============================] - 1s 777ms/step - loss: 0.3631 - mse: 0.3631 - val_loss: 1.4005 - val_mse: 1.4005
# Epoch 7/20
# 1/1 [==============================] - 1s 742ms/step - loss: 0.3620 - mse: 0.3620 - val_loss: 1.1531 - val_mse: 1.1531
# Epoch 8/20
# 1/1 [==============================] - 1s 698ms/step - loss: 0.3597 - mse: 0.3597 - val_loss: 1.1901 - val_mse: 1.1901
# Epoch 9/20
# 1/1 [==============================] - 1s 711ms/step - loss: 0.3573 - mse: 0.3573 - val_loss: 1.3245 - val_mse: 1.3245
# Epoch 10/20
# 1/1 [==============================] - 1s 717ms/step - loss: 0.3562 - mse: 0.3562 - val_loss: 1.2174 - val_mse: 1.2174
# Epoch 11/20
# 1/1 [==============================] - 1s 695ms/step - loss: 0.3537 - mse: 0.3537 - val_loss: 1.2223 - val_mse: 1.2223
# Epoch 12/20
# 1/1 [==============================] - 1s 694ms/step - loss: 0.3513 - mse: 0.3513 - val_loss: 1.2802 - val_mse: 1.2802
# Epoch 13/20
# 1/1 [==============================] - 1s 713ms/step - loss: 0.3501 - mse: 0.3501 - val_loss: 1.1593 - val_mse: 1.1593
# Epoch 14/20
# 1/1 [==============================] - 1s 703ms/step - loss: 0.3485 - mse: 0.3485 - val_loss: 1.2858 - val_mse: 1.2858
# Epoch 15/20
# 1/1 [==============================] - 1s 703ms/step - loss: 0.3457 - mse: 0.3457 - val_loss: 1.2875 - val_mse: 1.2875
# Epoch 16/20
# 1/1 [==============================] - 1s 699ms/step - loss: 0.3437 - mse: 0.3437 - val_loss: 1.2016 - val_mse: 1.2016
# Epoch 17/20
# 1/1 [==============================] - 1s 696ms/step - loss: 0.3425 - mse: 0.3425 - val_loss: 1.4030 - val_mse: 1.4030
# Epoch 18/20
# 1/1 [==============================] - 1s 696ms/step - loss: 0.3416 - mse: 0.3416 - val_loss: 1.2167 - val_mse: 1.2167
# Epoch 19/20
# 1/1 [==============================] - 1s 697ms/step - loss: 0.3402 - mse: 0.3402 - val_loss: 1.4683 - val_mse: 1.4683
# Epoch 20/20
# 1/1 [==============================] - 1s 686ms/step - loss: 0.3375 - mse: 0.3375 - val_loss: 1.3570 - val_mse: 1.3570

# %%
test_loss = model.evaluate([OHLCE_test, X_test_settlement], y_test_settlement)
print("Test Loss:", test_loss)

# 查看測試輸出
y_pred_settlement = model.predict([OHLCE_test, X_test_settlement])
# Out:
# 18/18 [==============================] - 0s 7ms/step - loss: 0.5052 - mse: 0.5052
# Test Loss: [0.5052134990692139, 0.5052134990692139]
# 18/18 [==============================] - 0s 6ms/step

# %%
columns_names = ['履約價(收盤價)', '履約價(結算價)', '隱含波動率(收盤價)', '隱含波動率(結算價)']
column_index = [IV_data.columns.get_loc(col) for col in columns_names]
ForecastIV = np.zeros(((len(y_pred_settlement), K_num)))



for i in range(len(y_pred_settlement)):
    x = IV_matrix_test[i*K_num:(i+1)*K_num, column_index[1]]
    v0 = IV_matrix_test[i*K_num, column_index[3]]
    ForecastIV[i] = recovery_curve(x, y_pred_settlement[i]/(magnification_slope), y0=v0)
ForecastIV = np.reshape(ForecastIV,(-1,1))
Forecast_matrix  = np.hstack((IV_matrix_test, ForecastIV))
column = np.hstack((IV_data.columns.to_numpy(), np.array(['預測隱含波動率(結算價)'])))
Forecast_Data = pd.DataFrame(data=Forecast_matrix, columns=column)


Forecast_Data.to_csv(output_dir_path + 'sRange03.csv', index=False, encoding='Big5')
